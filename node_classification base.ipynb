# %%
import torch
import torch.nn.functional as F
from torch_geometric.datasets import Flickr
from torch_geometric.nn import GCNConv
from torch_geometric.loader import NeighborLoader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import torch
#       2 import torch.nn.functional as F
# ----> 3 from torch_geometric.datasets import Flickr
#       4 from torch_geometric.nn import GCNConv
#       5 from torch_geometric.loader import NeighborLoader
#
# File ~/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/datasets/__init__.py:3
#       1 # flake8: noqa
# ----> 3 from .karate import KarateClub
#       4 from .tu_dataset import TUDataset
#       5 from .gnn_benchmark_dataset import GNNBenchmarkDataset
#
# File ~/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/datasets/karate.py:5
#       1 from typing import Callable, Optional
#       3 import torch
# ----> 5 from torch_geometric.data import Data, InMemoryDataset
#       8 class KarateClub(InMemoryDataset):
#       9     r"""Zachary's karate club network from the `"An Information Flow Model for
#      10     Conflict and Fission in Small Groups"
#      11     <https://www.journals.uchicago.edu/doi/abs/10.1086/jar.33.4.3629752>`_
#    (...)
#      39           - 4
#      40     """
#
# File ~/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/data/__init__.py:8
#       6 from .feature_store import FeatureStore, TensorAttr
#       7 from .graph_store import GraphStore, EdgeAttr, EdgeLayout
# ----> 8 from .data import Data
#       9 from .hetero_data import HeteroData
#      10 from .batch import Batch
#
# File ~/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/data/data.py:27
#      25 from torch_geometric.data.feature_store import _FieldStatus
#      26 from torch_geometric.data.graph_store import EdgeLayout
# ---> 27 from torch_geometric.data.storage import (
#      28     BaseStorage,
#      29     EdgeStorage,
#      30     GlobalStorage,
#      31     NodeStorage,
#      32 )
#      33 from torch_geometric.deprecation import deprecated
#      34 from torch_geometric.index import Index
#
# File ~/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/data/storage.py:27
#      24 from torch import Tensor
#      25 from typing_extensions import Self
# ---> 27 from torch_geometric import EdgeIndex
#      28 from torch_geometric.data.view import ItemsView, KeysView, ValuesView
#      29 from torch_geometric.typing import (
#      30     EdgeType,
#      31     NodeType,
#      32     SparseTensor,
#      33     TensorFrame,
#      34 )
#
# File ~/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/__init__.py:18
#      16 import torch_geometric.utils
#      17 import torch_geometric.data
# ---> 18 import torch_geometric.sampler
#      19 import torch_geometric.loader
#      20 import torch_geometric.transforms
#
# File ~/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/sampler/__init__.py:3
#       1 r"""Graph sampler package."""
# ----> 3 from .base import (BaseSampler, NodeSamplerInput, EdgeSamplerInput,
#       4                    SamplerOutput, HeteroSamplerOutput, NegativeSampling,
#       5                    NumNeighbors)
#       6 from .neighbor_sampler import NeighborSampler
#       7 from .hgt_sampler import HGTSampler
#
# File ~/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/sampler/base.py:13
#      10 import torch
#      11 from torch import Tensor
# ---> 13 from torch_geometric.data import Data, FeatureStore, GraphStore, HeteroData
#      14 from torch_geometric.sampler.utils import to_bidirectional
#      15 from torch_geometric.typing import EdgeType, EdgeTypeStr, NodeType, OptTensor
#
# ImportError: cannot import name 'Data' from partially initialized module 'torch_geometric.data' (most likely due to a circular import) (/home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages/torch_geometric/data/__init__.py)

# %%
# !pip install --upgrade torch torchvision torchaudio
# !pip install --upgrade torch-geometric
# !pip install --upgrade torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric
# Out:
# Requirement already satisfied: torch in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (2.5.1+cu121)
# Collecting torch
#   Downloading torch-2.6.0-cp39-cp39-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: torchvision in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (0.20.1+cu121)
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp39-cp39-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: torchaudio in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (2.5.1+cu121)
# Collecting torchaudio
#   Downloading torchaudio-2.6.0-cp39-cp39-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch) (2024.2.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch) (9.1.0.70)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch) (2.21.5)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch)
#   Downloading triton-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: sympy==1.13.1 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torchvision) (1.26.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from jinja2->torch) (2.1.5)
# Downloading torch-2.6.0-cp39-cp39-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 18.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 24.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 18.3 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 21.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 23.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 26.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 27.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 24.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 17.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading triton-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.1/253.1 MB 23.0 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.21.0-cp39-cp39-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 10.6 MB/s eta 0:00:0000:0100:01
# Downloading torchaudio-2.6.0-cp39-cp39-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 11.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: triton, nvidia-cusparselt-cu12, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.1.105
#     Uninstalling nvidia-nvtx-cu12-12.1.105:
#       Successfully uninstalled nvidia-nvtx-cu12-12.1.105
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.1.105
#     Uninstalling nvidia-nvjitlink-cu12-12.1.105:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.1.105
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.2.106
#     Uninstalling nvidia-curand-cu12-10.3.2.106:
#       Successfully uninstalled nvidia-curand-cu12-10.3.2.106
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.0.2.54
#     Uninstalling nvidia-cufft-cu12-11.0.2.54:
#       Successfully uninstalled nvidia-cufft-cu12-11.0.2.54
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.1.105
#     Uninstalling nvidia-cuda-runtime-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.1.105
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.1.105
#     Uninstalling nvidia-cuda-cupti-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.1.105
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.1.3.1
#     Uninstalling nvidia-cublas-cu12-12.1.3.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.1.3.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.1.0.106
#     Uninstalling nvidia-cusparse-cu12-12.1.0.106:
#       Successfully uninstalled nvidia-cusparse-cu12-12.1.0.106
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.4.5.107
#     Uninstalling nvidia-cusolver-cu12-11.4.5.107:
#       Successfully uninstalled nvidia-cusolver-cu12-11.4.5.107
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.1+cu121
#     Uninstalling torchaudio-2.5.1+cu121:
#       Successfully uninstalled torchaudio-2.5.1+cu121
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 torch-2.6.0 torchaudio-2.6.0 torchvision-0.21.0 triton-3.2.0
# Requirement already satisfied: torch-geometric in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (2.6.1)
# Requirement already satisfied: aiohttp in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (3.11.11)
# Requirement already satisfied: fsspec in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (2024.2.0)
# Requirement already satisfied: jinja2 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (3.1.3)
# Requirement already satisfied: numpy in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (1.26.3)
# Requirement already satisfied: psutil>=5.8.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (6.1.1)
# Requirement already satisfied: pyparsing in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (3.2.1)
# Requirement already satisfied: requests in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: tqdm in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from jinja2->torch-geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from requests->torch-geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from requests->torch-geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from requests->torch-geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from requests->torch-geometric) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from multidict<7.0,>=4.5->aiohttp->torch-geometric) (4.12.2)
# Collecting torch-scatter
#   Downloading torch_scatter-2.1.2.tar.gz (108 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torch-sparse
#   Downloading torch_sparse-0.6.18.tar.gz (209 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torch-cluster
#   Downloading torch_cluster-1.6.3.tar.gz (54 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torch-spline-conv
#   Downloading torch_spline_conv-1.2.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch-geometric in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (2.6.1)
# Requirement already satisfied: scipy in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-sparse) (1.13.1)
# Requirement already satisfied: aiohttp in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (3.11.11)
# Requirement already satisfied: fsspec in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (2024.2.0)
# Requirement already satisfied: jinja2 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (3.1.3)
# Requirement already satisfied: numpy in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (1.26.3)
# Requirement already satisfied: psutil>=5.8.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (6.1.1)
# Requirement already satisfied: pyparsing in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (3.2.1)
# Requirement already satisfied: requests in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: tqdm in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from aiohttp->torch-geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from jinja2->torch-geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from requests->torch-geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from requests->torch-geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from requests->torch-geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from requests->torch-geometric) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/vamsi/miniconda3/envs/isl/lib/python3.9/site-packages (from multidict<7.0,>=4.5->aiohttp->torch-geometric) (4.12.2)
# Building wheels for collected packages: torch-scatter, torch-sparse, torch-cluster, torch-spline-conv
#   Building wheel for torch-scatter (setup.py) ... done
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.2-cp39-cp39-linux_x86_64.whl size=3836553 sha256=28a38f0339d182bf1aae73a8fb7872ac732eb1b09922af882d272bd2d8ae4791
#   Stored in directory: /home/vamsi/.cache/pip/wheels/b8/9c/c0/d261e1e64cc49e6b14dd7319d8b61eb14168529d810dbba00e
#   Building wheel for torch-sparse (setup.py) ... done
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.18-cp39-cp39-linux_x86_64.whl size=2904370 sha256=5411d90c33e9cae68152252dceab0913a31f1a51a26e1b06ff05f1d7d833847f
#   Stored in directory: /home/vamsi/.cache/pip/wheels/c0/15/18/881c60adefeb60882987c23aa5ecced0ab7257c3162acab518
#   Building wheel for torch-cluster (setup.py) ... done
#   Created wheel for torch-cluster: filename=torch_cluster-1.6.3-cp39-cp39-linux_x86_64.whl size=2069723 sha256=008fa1c647ba21497b57abb3e1720ca84e148ba2148e91cb9e872b8af277f57c
#   Stored in directory: /home/vamsi/.cache/pip/wheels/fc/55/f3/d8a310d8f0c29653a7580789f3b53f15e3cd2e88ff8ed5eeb5
#   Building wheel for torch-spline-conv (setup.py) ... |

# %%
# Load the Flickr dataset
dataset = Flickr(root='data/Flickr')
data = dataset[0]  # The dataset contains a single graph

# Define a simple Graph Convolutional Network (GCN)
class GCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# Initialize the model, optimizer, and loss function
model = GCN(in_channels=data.num_features, hidden_channels=64, out_channels=dataset.num_classes)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
loss_fn = torch.nn.NLLLoss()

# Split the dataset into train, validation, and test sets
train_mask, val_mask, test_mask = data.train_mask, data.val_mask, data.test_mask

# Training loop
def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = loss_fn(out[train_mask], data.y[train_mask])
    loss.backward()
    optimizer.step()
    return loss.item()

# Evaluation function
def evaluate(mask):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1)
        correct = (pred[mask] == data.y[mask]).sum()
        acc = correct / mask.sum()
    return acc.item()

# Train the model
for epoch in range(200):
    loss = train()
    if epoch % 20 == 0:
        val_acc = evaluate(val_mask)
        print(f'Epoch {epoch}, Loss: {loss:.4f}, Val Accuracy: {val_acc:.4f}')

# Test the model
test_acc = evaluate(test_mask)
print(f'Test Accuracy: {test_acc:.4f}')
